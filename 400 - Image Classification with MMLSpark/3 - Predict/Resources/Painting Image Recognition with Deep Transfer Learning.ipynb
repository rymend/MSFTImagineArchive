# %% [markdown]
# # Painting Image Recognition with Deep Transfer Learning
#
# This hands-on tutorial shows how to use [Transfer Learning](https://en.wikipedia.org/wiki/Inductive_transfer) to take an existing trained model and adapt it to the painting data.
#
# This notebook lab adapts and updates the tutorial from the Microsoft tutorial at https://github.com/Microsoft/CNTK/blob/master/Tutorials/CNTK_301_Image_Recognition_with_Deep_Transfer_Learning.ipynb.
#
# ## Problem
# You acquired a set of painting images which need to be classified.
#
#
# However, the number of images is far less than what is needed to train a state-of-the-art classifier such as a [Residual Network](https://github.com/KaimingHe/deep-residual-networks). You have a rich annotated data set of images of natural scene images such as shown below (courtesy [t-SNE visualization site](http://cs.stanford.edu/people/karpathy/cnnembed/)).
#
# ![](http://www.cntk.ai/jup/cntk301_imagenet.jpg)
#
# This tutorial introduces deep transfer learning as a means to leverage multiple data sources to overcome data scarcity problem.
#
# ### Why Transfer Learning?
#
# As stated above, Transfer Learning is a useful technique when, for instance, you know you need to classify incoming images into different categories, but you do not have enough data to train a Deep Neural Network (DNN) from scratch. Training DNNs takes a lot of data, all of it labeled, and often you will not have that kind of data on hand. If your problem is similar to one for which a network has already been trained, though, you can use Transfer Learning to modify that network to your problem with a fraction of the labeled images (we are talking tens instead of thousands).
#
# ### What is Transfer Learning?
#
# With Transfer Learning, we use an existing trained model and adapt it to our own problem. We are essentially building upon the features and concepts that were learned during the training of the base model. With a Convolutional DNN (ResNet_18 in this case), we are using the features learned from ImageNet data and _cutting off_ the final classification layer, replacing it with a new dense layer that will predict the class labels of our new domain.
#
# The input to the old and the new prediction layer is the same, we simply reuse the trained features. Then we train this modified network, either only the new weights of the new prediction layer or all weights of the entire network.
#
# This can be used, for instance, when we have a small set of images that are in a similar domain to an existing trained model. Training a Deep Neural Network from scratch requires tens of thousands of images, but training one that has already learned features in the domain you are adapting it to requires far fewer.
#
#
# In our case, this means adapting a network trained on ImageNet images (dogs, cats, birds, etc.) to paintings. However, Transfer Learning has also been successfully used to adapt existing neural models for translation, speech synthesis, and many other domains - it is a convenient way to bootstrap your learning process.
#
# **Importing CNTK and other useful libraries**
#
# Microsoft's Cognitive Toolkit comes in Python form as `cntk`, and contains many useful submodules for IO, defining layers, training models, and interrogating trained models. We will need many of these for Transfer Learning, as well as some other common libraries for downloading files, unpacking/unzipping them, working with the file system, and loading matrices.

# %%
from __future__ import print_function
import glob
import os
import numpy as np
from PIL import Image
import requests
# Some of the flowers data is stored as .mat files
from scipy.io import loadmat
from shutil import copyfile
import sys
import tarfile
import time

# Load the right urlretrieve based on python version
try: 
    from urllib.request import urlretrieve 
except ImportError: 
    from urllib import urlretrieve
    
import zipfile
from pathlib import Path

# Useful for being able to dump images into the Notebook
import IPython.display as D

# Import CNTK and helpers
import cntk as C
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>8</td><td>application_1514805782323_0018</td><td>pyspark3</td><td>idle</td><td><a target="_blank" href="http://hn1-hdimag.qxw0feubjm5unko0x2iehk4ygg.jx.internal.cloudapp.net:8088/proxy/application_1514805782323_0018/">Link</a></td><td><a target="_blank" href="http://10.0.0.10:30060/node/containerlogs/container_1514805782323_0018_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# SparkSession available as 'spark'.

# %% [markdown]
# There are two run modes:
# - *Fast mode*: `isFast` is set to `True`. This is the default mode for the notebooks, which means we train for fewer iterations or train / test on limited data. This ensures functional correctness of the notebook though the models produced are far from what a completed training would produce.
#
# - *Slow mode*: We recommend the user to set this flag to `False` once the user has gained familiarity with the notebook content and wants to gain insight from running the notebooks for a longer period with different parameters for training.
#
# For *Fast mode* we train the model for 5 epochs and results have low accuracy but is good enough for development. The model yields good accuracy after 10-20 epochs.
#
# Feel free to adjust the learning_params below and observe the results. You can tweak the **max_epochs** to train for longer, **mb_size** to adjust the size of each minibatch, or **lr_per_mb** to play with the speed of convergence (learning rate).
#
# Note that if you've already trained the model, you will want to set force_retraining to **True** to force the Notebook to re-train your model with the new parameters.

# %%
isFast = True

# Set parameters for the transfer learning
force_retraining = True

max_training_epochs = 5 if isFast else 20

learning_params = {
    'max_epochs': max_training_epochs,
    'mb_size': 50,
    'lr_per_mb': [0.2]*10 + [0.1],
    'momentum_per_mb': 0.9,
    'l2_reg_weight': 0.0005,
    'freeze_weights': True
}

# %% [markdown]
# ### Data Access
#
# The data has already been uploaded to the attached Azure Blob Storage.  However, we also need to download an already trained image model.

# %%
# By default, we store data in the Image directory
data_root = os.path.abspath(os.path.join('..', 'Image'))
    
datasets_path = os.path.join(data_root, 'DataSets')
output_path = os.path.abspath(os.path.join('.', 'temp', 'Output'))

def ensure_exists(path):
    if not os.path.exists(path):
        os.makedirs(path)
        
def download_unless_exists(url, filename, max_retries=3):
    '''Download the file unless it already exists, with retry. Throws if all retries fail.'''
    if os.path.exists(filename):
        print('Reusing locally cached: ', filename)
    else:
        print('Starting download of {} to {}'.format(url, filename))
        retry_cnt = 0
        while True:
            try:
                urlretrieve(url, filename)
                print('Download completed.')
                return
            except:
                retry_cnt += 1
                if retry_cnt == max_retries:
                    print('Exceeded maximum retry count, aborting.')
                    raise
                print('Failed to download, retrying.')
                time.sleep(np.random.randint(1,10))        

def download_model(model_root = os.path.join(data_root, 'PretrainedModels')):
    ensure_exists(model_root)
    resnet18_model_uri = 'https://www.cntk.ai/Models/ResNet/ResNet_18.model'
    resnet18_model_local = os.path.join(model_root, 'ResNet_18.model')
    download_unless_exists(resnet18_model_uri, resnet18_model_local)
    print('Downloaded model to: ', Path(resnet18_model_local).resolve())
    return resnet18_model_local

# %%
print (Path(datasets_path).resolve())
# Out:
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets

# %%
outdir = os.path.join(datasets_path,'Paintings/Train/MonetPainting/')
print(outdir)
os.makedirs(os.path.join(datasets_path,'Paintings/Train/MonetPainting/'))
os.makedirs(os.path.join(datasets_path,'Paintings/Train/VanGoghPainting/'))
os.makedirs(os.path.join(datasets_path,'Paintings/Train/PicassoPainting/'))
os.makedirs(os.path.join(datasets_path,'Paintings/Test/MonetPainting/'))
os.makedirs(os.path.join(datasets_path,'Paintings/Test/VanGoghPainting/'))
os.makedirs(os.path.join(datasets_path,'Paintings/Test/PicassoPainting/'))
# Out:
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/

# %%
azure_blob_root = 'wasbs://images@marktabblob.blob.core.windows.net/'
paintings_stem = 'Image/DataSets/Paintings/'
training_stem = paintings_stem + 'Train/'
testing_stem = paintings_stem + 'Test/'

# "Downloading" the image files from the Azure Blob Storage uri into the Linux file system
def download_paintings_dataset(dataset_root = os.path.join(datasets_path, 'Paintings')):
    ensure_exists(dataset_root)
    
    uniqueclasseslocation = azure_blob_root + paintings_stem + 'uniqueclasses.txt'
    uniqueclassesfile = spark.sparkContext.textFile(uniqueclasseslocation)  
    
    transferfilelocation = azure_blob_root + paintings_stem + 'transferimages.txt'
    transferfile = spark.sparkContext.textFile(transferfilelocation)
    for row in transferfile.collect():
        uri = str(row.split(' ', 1)[0])
        filename = os.path.join(dataset_root, str(row.split(' ', 1)[1]))

        #f = open(filename,'wb')
        #f.write(requests.get(uri).content)
        #f.close()
        download_unless_exists(uri, filename) 
        print("uri: ", uri, "  ", "filename: ", filename)
    return {
        'training_folder': os.path.join(dataset_root, 'Train'),
        'testing_folder': os.path.join(dataset_root, 'Test'),
        'azure_training_map': os.path.join(azure_blob_root, training_stem, 'map.txt'),
        'azure_testing_map': os.path.join(azure_blob_root, testing_stem, 'map.txt'),
        'num_classes': uniqueclassesfile.take(1)[0]     
    }

print('Downloading paintings from Azure Blob Storage to Linux file system, this might take a while...')
paintings_data = download_paintings_dataset()
print('All data now available to the notebook!')

paintings_data
# Out:
# Downloading paintings from Azure Blob Storage to Linux file system, this might take a while...
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/001c0.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/001c0.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/001c0.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/001c0.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/PicassoPainting/001c2.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/PicassoPainting/001c2.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/PicassoPainting/001c2.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/PicassoPainting/001c2.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/PicassoPainting/0030.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/PicassoPainting/0030.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/PicassoPainting/0030.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/PicassoPainting/0030.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/01110.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/01110.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/01110.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/01110.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/04198.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/04198.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/04198.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/04198.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/061c8.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/061c8.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/061c8.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/061c8.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/061db.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/061db.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/061db.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/061db.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/VanGoghPainting/061dc.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/061dc.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/VanGoghPainting/061dc.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/061dc.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/06c8.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/06c8.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/06c8.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/06c8.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/VanGoghPainting/06f8.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/VanGoghPainting/06f8.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/VanGoghPainting/06f8.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/VanGoghPainting/06f8.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/09100.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/09100.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/09100.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/09100.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/09107.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/09107.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/09107.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/09107.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/09111.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/09111.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/09111.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/09111.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/0918.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/0918.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/0918.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/0918.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/091be.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/091be.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/091be.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/091be.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/0940.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/0940.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/0940.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/0940.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/VanGoghPainting/0978.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/0978.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/VanGoghPainting/0978.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/0978.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/MonetPainting/0c01.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/MonetPainting/0c01.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/MonetPainting/0c01.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/MonetPainting/0c01.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/VanGoghPainting/0c0d.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/VanGoghPainting/0c0d.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/VanGoghPainting/0c0d.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/VanGoghPainting/0c0d.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/0c110.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/0c110.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/0c110.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/0c110.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/PicassoPainting/0c40.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/PicassoPainting/0c40.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/PicassoPainting/0c40.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/PicassoPainting/0c40.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/VanGoghPainting/100180.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/100180.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/VanGoghPainting/100180.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/100180.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/100188.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/100188.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/100188.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/100188.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/1001e4.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/1001e4.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/1001e4.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/1001e4.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/1001f9.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/1001f9.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/1001f9.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/1001f9.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/PicassoPainting/1001fa.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/PicassoPainting/1001fa.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/PicassoPainting/1001fa.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/PicassoPainting/1001fa.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/PicassoPainting/1011e6.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/PicassoPainting/1011e6.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test
jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/db19.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/db1f.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/db1f.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/db1f.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/db1f.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/MonetPainting/db27.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/MonetPainting/db27.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Test/MonetPainting/db27.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test/MonetPainting/db27.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/db2f.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/db2f.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/db2f.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/db2f.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/db32.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/db32.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/db32.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/db32.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/db69.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/db69.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/db69.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/db69.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/dba3.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/dba3.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/dba3.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/dba3.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/VanGoghPainting/dd18.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/dd18.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/VanGoghPainting/dd18.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/dd18.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/de76.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/de76.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/de76.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/de76.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/df1b8.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/df1b8.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/df1b8.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/df1b8.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/e6c8.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/e6c8.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/e6c8.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/e6c8.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/VanGoghPainting/e935.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/e935.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/VanGoghPainting/e935.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/e935.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/ecbf.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/ecbf.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/ecbf.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/ecbf.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/ee88.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/ee88.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/ee88.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/ee88.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/eec8.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/eec8.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/eec8.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/eec8.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/f1f7.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/f1f7.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/f1f7.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/f1f7.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/f3a7.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/f3a7.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/f3a7.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/f3a7.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/f5d0.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/f5d0.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/f5d0.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/f5d0.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/f61f8.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/f61f8.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/f61f8.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/f61f8.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/f6c0.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/f6c0.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/f6c0.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/f6c0.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/f6fc.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/f6fc.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/f6fc.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/f6fc.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/f6ff.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/f6ff.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/f6ff.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/f6ff.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/fb03.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/fb03.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/fb03.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/fb03.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/fd80.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/fd80.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/fd80.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/fd80.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/fdc3.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/fdc3.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/PicassoPainting/fdc3.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/fdc3.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/fe1f8.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/fe1f8.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/MonetPainting/fe1f8.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/fe1f8.jpeg
# Starting download of https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/VanGoghPainting/ff1f0.jpeg to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/ff1f0.jpeg
# Download completed.
# uri:  https://marktabblob.blob.core.windows.net/images/Image/DataSets/Paintings/Train/VanGoghPainting/ff1f0.jpeg    filename:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/ff1f0.jpeg
# All data now available to the notebook!
# {'testing_folder': '/mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Test', 'num_classes': '3', 'azure_testing_map': 'wasbs://images@marktabblob.blob.core.windows.net/Image/DataSets/Paintings/Test/map.txt', 'training_folder': '/mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train', 'azure_training_map': 'wasbs://images@marktabblob.blob.core.windows.net/Image/DataSets/Paintings/Train/map.txt'}

# %% [markdown]
# ### Pre-Trained Model (ResNet)
#
# For this task, we have chosen ResNet_18 as our trained model and  will it as the base model. This model will be adapted using Transfer Learning for classification of flowers and animals. This model is a [Convolutional Neural Network](https://en.wikipedia.org/wiki/Convolutional_neural_network) built using [Residual Network](https://github.com/KaimingHe/deep-residual-networks) techniques. Convolutional Neural Networks build up layers of convolutions, transforming an input image and distilling it down until they start recognizing composite features, with deeper layers of convolutions recognizing complex patterns are made possible. The author of Keras has a [fantastic post](https://blog.keras.io/how-convolutional-neural-networks-see-the-world.html) where he describes how Convolutional Networks "see the world" which gives a much more detailed explanation.
#
# Residual Deep Learning is a technique that originated in Microsoft Research and involves "passing through" the main signal of the input data, so that the network winds up "learning" on just the residual portions that differ between layers. This has proven, in practice, to allow the training of much deeper networks by avoiding issues that plague gradient descent on larger networks. These cells bypass convolution layers and then come back in later before ReLU (see below), but some have argued that even deeper networks can be built by avoiding even more nonlinearities in the bypass channel. This is an area of hot research right now, and one of the most exciting parts of Transfer Learning is that you get to benefit from all of the improvements by just integrating new trained models.
#
# ![](https://adeshpande3.github.io/assets/ResNet.png)

# %%
print('Downloading pre-trained model. Note: this might take a while...')
# Download pretrained model to a Linux directory attached to this application instance
base_model_file = download_model()
print('Downloading pre-trained model complete!')
# Out:
# Downloading pre-trained model. Note: this might take a while...
# Starting download of https://www.cntk.ai/Models/ResNet/ResNet_18.model to /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/PretrainedModels/ResNet_18.model
# Download completed.
# Downloaded model to:  /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/PretrainedModels/ResNet_18.model
# Downloading pre-trained model complete!

# %% [markdown]
# ### Inspecting pre-trained model
#
# We print out all of the layers in ResNet_18 to show you how you can interrogate a model - to use a different model than ResNet_18 you would just need to discover the appropriate last hidden layer and feature layer to use. CNTK provides a convenient `get_node_outputs` method under `cntk.graph` to allow you to dump all of the model details. We can recognize the final hidden layer as the one before we start computing the final classification into the 1000 ImageNet classes (so in this case, `z.x`).

# %%
# define base model location and characteristics
base_model = {
    'model_file': base_model_file,
    'feature_node_name': 'features',
    'last_hidden_node_name': 'z.x',
    # Channel Depth x Height x Width
    'image_dims': (3, 224, 224)
}

# Print out all layers in the model
print('Loading {} and printing all layers:'.format(base_model['model_file']))
node_outputs = C.logging.get_node_outputs(C.load_model(base_model['model_file']))
for l in node_outputs: print("  {0} {1}".format(l.name, l.shape))
# Out:
# Loading /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/PretrainedModels/ResNet_18.model and printing all layers:
#   ce ()
#   errs ()
#   top5Errs ()
#   z (1000,)
#   ce ()
#   z (1000,)
#   z.PlusArgs[0] (1000,)
#   z.x (512, 1, 1)
#   z.x.x.r (512, 7, 7)
#   z.x.x.p (512, 7, 7)
#   z.x.x.b (512, 7, 7)
#   z.x.x.b.x.c (512, 7, 7)
#   z.x.x.b.x (512, 7, 7)
#   z.x.x.b.x._ (512, 7, 7)
#   z.x.x.b.x._.x.c (512, 7, 7)
#   z.x.x.x.r (512, 7, 7)
#   z.x.x.x.p (512, 7, 7)
#   z.x.x.x.b (512, 7, 7)
#   z.x.x.x.b.x.c (512, 7, 7)
#   z.x.x.x.b.x (512, 7, 7)
#   z.x.x.x.b.x._ (512, 7, 7)
#   z.x.x.x.b.x._.x.c (512, 7, 7)
#   _z.x.x.x.r (512, 7, 7)
#   _z.x.x.x.p (512, 7, 7)
#   _z.x.x.x.b (512, 7, 7)
#   _z.x.x.x.b.x.c (512, 7, 7)
#   _z.x.x.x.b.x (512, 7, 7)
#   _z.x.x.x.b.x._ (512, 7, 7)
#   _z.x.x.x.b.x._.x.c (512, 7, 7)
#   z.x.x.x.x.r (256, 14, 14)
#   z.x.x.x.x.p (256, 14, 14)
#   z.x.x.x.x.b (256, 14, 14)
#   z.x.x.x.x.b.x.c (256, 14, 14)
#   z.x.x.x.x.b.x (256, 14, 14)
#   z.x.x.x.x.b.x._ (256, 14, 14)
#   z.x.x.x.x.b.x._.x.c (256, 14, 14)
#   z.x.x.x.x.x.r (256, 14, 14)
#   z.x.x.x.x.x.p (256, 14, 14)
#   z.x.x.x.x.x.b (256, 14, 14)
#   z.x.x.x.x.x.b.x.c (256, 14, 14)
#   z.x.x.x.x.x.b.x (256, 14, 14)
#   z.x.x.x.x.x.b.x._ (256, 14, 14)
#   z.x.x.x.x.x.b.x._.x.c (256, 14, 14)
#   z.x.x.x.x.x.x.r (128, 28, 28)
#   z.x.x.x.x.x.x.p (128, 28, 28)
#   z.x.x.x.x.x.x.b (128, 28, 28)
#   z.x.x.x.x.x.x.b.x.c (128, 28, 28)
#   z.x.x.x.x.x.x.b.x (128, 28, 28)
#   z.x.x.x.x.x.x.b.x._ (128, 28, 28)
#   z.x.x.x.x.x.x.b.x._.x.c (128, 28, 28)
#   z.x.x.x.x.x.x.x.r (128, 28, 28)
#   z.x.x.x.x.x.x.x.p (128, 28, 28)
#   z.x.x.x.x.x.x.x.b (128, 28, 28)
#   z.x.x.x.x.x.x.x.b.x.c (128, 28, 28)
#   z.x.x.x.x.x.x.x.b.x (128, 28, 28)
#   z.x.x.x.x.x.x.x.b.x._ (128, 28, 28)
#   z.x.x.x.x.x.x.x.b.x._.x.c (128, 28, 28)
#   z.x.x.x.x.x.x.x.x.r (64, 56, 56)
#   z.x.x.x.x.x.x.x.x.p (64, 56, 56)
#   z.x.x.x.x.x.x.x.x.b (64, 56, 56)
#   z.x.x.x.x.x.x.x.x.b.x.c (64, 56, 56)
#   z.x.x.x.x.x.x.x.x.b.x (64, 56, 56)
#   z.x.x.x.x.x.x.x.x.b.x._ (64, 56, 56)
#   z.x.x.x.x.x.x.x.x.b.x._.x.c (64, 56, 56)
#   z.x.x.x.x.x.x.x.x.x.r (64, 56, 56)
#   z.x.x.x.x.x.x.x.x.x.p (64, 56, 56)
#   z.x.x.x.x.x.x.x.x.x.b (64, 56, 56)
#   z.x.x.x.x.x.x.x.x.x.b.x.c (64, 56, 56)
#   z.x.x.x.x.x.x.x.x.x.b.x (64, 56, 56)
#   z.x.x.x.x.x.x.x.x.x.b.x._ (64, 56, 56)
#   z.x.x.x.x.x.x.x.x.x.b.x._.x.c (64, 56, 56)
#   z.x.x.x.x.x.x.x.x.x (64, 56, 56)
#   z.x.x.x.x.x.x.x.x.x.x (64, 112, 112)
#   z.x.x.x.x.x.x.x.x.x.x._ (64, 112, 112)
#   z.x.x.x.x.x.x.x.x.x.x._.x.c (64, 112, 112)
#   z.x.x.x.x.x.x.x.s (128, 28, 28)
#   z.x.x.x.x.x.x.x.s.x.c (128, 28, 28)
#   z.x.x.x.x.x.s (256, 14, 14)
#   z.x.x.x.x.x.s.x.c (256, 14, 14)
#   z.x.x.x.s (512, 7, 7)
#   z.x.x.x.s.x.c (512, 7, 7)
#   errs ()
#   top5Errs ()

# %% [markdown]
# ### Training the Transfer Learning Model
#
# In the code below, we load up the pre-trained ResNet_18 model and clone it, while stripping off the final `features` layer. We clone the model so that we can re-use the same trained model multiple times, trained for different things - it is not strictly necessary if you are just training it for a single task, but this is why we would not use `CloneMethod.share`, we want to learn new parameters. If `freeze_weights` is true, we will freeze weights on all layers we clone and only learn weights on the final new features layer. This can often be useful if you are cloning higher up the tree (e.g., cloning after the first convolutional layer to just get basic image features).
#
# We find the final hidden layer (`z.x`) using `find_by_name`, clone it and all of its predecessors, then attach a new `Dense` layer for classification.

# %%
import cntk.io.transforms as xforms
ensure_exists(output_path)
np.random.seed(123)

# Creates a minibatch source for training or testing
def create_mb_source(map_file, image_dims, num_classes, randomize=True):
    transforms = [xforms.scale(width=image_dims[2], height=image_dims[1], channels=image_dims[0], interpolations='linear')]
    return C.io.MinibatchSource(C.io.ImageDeserializer(map_file, C.io.StreamDefs(
            features=C.io.StreamDef(field='image', transforms=transforms),
            labels=C.io.StreamDef(field='label', shape=num_classes))),
            randomize=randomize)

# Creates the network model for transfer learning
def create_model(model_details, num_classes, input_features, new_prediction_node_name='prediction', freeze=False):
    # Load the pretrained classification net and find nodes
    base_model = C.load_model(model_details['model_file'])
    feature_node = C.logging.find_by_name(base_model, model_details['feature_node_name'])
    last_node = C.logging.find_by_name(base_model, model_details['last_hidden_node_name'])

    # Clone the desired layers with fixed weights
    cloned_layers = C.combine([last_node.owner]).clone(
        C.CloneMethod.freeze if freeze else C.CloneMethod.clone,
        {feature_node: C.placeholder(name='features')})

    # Add new dense layer for class prediction
    feat_norm = input_features - C.Constant(114)
    cloned_out = cloned_layers(feat_norm)
    z = C.layers.Dense(num_classes, activation=None, name=new_prediction_node_name) (cloned_out)

    return z

# %% [markdown]
# We will now train the model just like any other CNTK model training - instantiating an input source (in this case a `MinibatchSource` from our image data), defining the loss function, and training for a number of epochs. Since we are training a multi-class classifier network, the final layer is a cross-entropy Softmax, and the error function is classification error - both conveniently provided by utility functions in `cntk.ops`.
#
# When training a pre-trained model, we are adapting the existing weights to suit our domain. Since the weights are likely already close to correct (especially for earlier layers that find more primitive features), fewer examples and fewer epochs are typically required to get good performance.

# %%
# Trains a transfer learning model
def train_model(model_details, num_classes, train_map_file,
                learning_params, max_images=-1):
    num_epochs = learning_params['max_epochs']
    epoch_size = sum(1 for line in open(train_map_file))
    if max_images > 0:
        epoch_size = min(epoch_size, max_images)
    minibatch_size = learning_params['mb_size']
    
    # Create the minibatch source and input variables
    minibatch_source = create_mb_source(train_map_file, model_details['image_dims'], num_classes)
    image_input = C.input_variable(model_details['image_dims'])
    label_input = C.input_variable(num_classes)

    # Define mapping from reader streams to network inputs
    input_map = {
        image_input: minibatch_source['features'],
        label_input: minibatch_source['labels']
    }

    # Instantiate the transfer learning model and loss function
    tl_model = create_model(model_details, num_classes, image_input, freeze=learning_params['freeze_weights'])
    ce = C.cross_entropy_with_softmax(tl_model, label_input)
    pe = C.classification_error(tl_model, label_input)

    # Instantiate the trainer object
    lr_schedule = C.learning_parameter_schedule(learning_params['lr_per_mb'])
    mm_schedule = C.momentum_schedule(learning_params['momentum_per_mb'])
    learner = C.momentum_sgd(tl_model.parameters, lr_schedule, mm_schedule, 
                           l2_regularization_weight=learning_params['l2_reg_weight'])
    trainer = C.Trainer(tl_model, (ce, pe), learner)

    # Get minibatches of images and perform model training
    print("Training transfer learning model for {0} epochs (epoch_size = {1}).".format(num_epochs, epoch_size))
    C.logging.log_number_of_parameters(tl_model)
    progress_printer = C.logging.ProgressPrinter(tag='Training', num_epochs=num_epochs)
    for epoch in range(num_epochs):       # loop over epochs
        sample_count = 0
        while sample_count < epoch_size:  # loop over minibatches in the epoch
            data = minibatch_source.next_minibatch(min(minibatch_size, epoch_size - sample_count), input_map=input_map)
            trainer.train_minibatch(data)                                    # update model with it
            sample_count += trainer.previous_minibatch_sample_count          # count samples processed so far
            progress_printer.update_with_trainer(trainer, with_metric=True)  # log progress
            if sample_count % (100 * minibatch_size) == 0:
                print ("Processed {0} samples".format(sample_count))

        progress_printer.epoch_summary(with_metric=True)

    return tl_model

# %% [markdown]
# When we evaluate the trained model on an image, we have to massage that image into the expected format. In our case we use `Image` to load the image from its path, resize it to the size expected by our model, reverse the color channels (RGB to BGR), and convert to a contiguous array along height, width, and color channels. This corresponds to the 224x224x3 flattened array on which our model was trained.
#
# The model with which we are doing the evaluation has not had the Softmax and Error layers added, so is complete up to the final feature layer. To evaluate the image with the model, we send the input data to the `model.eval` method, `softmax` over the results to produce probabilities, and use Numpy's `argmax` method to determine the predicted class. We can then compare that against the true labels to get the overall model accuracy.

# %%
# Evaluates a single image using the re-trained model
def eval_single_image(loaded_model, image_path, image_dims):
    # load and format image (resize, RGB -> BGR, CHW -> HWC)
    try:
        img = Image.open(image_path)
        
        if image_path.endswith("png"):
            temp = Image.new("RGB", img.size, (255, 255, 255))
            temp.paste(img, img)
            img = temp
        resized = img.resize((image_dims[2], image_dims[1]), Image.ANTIALIAS)
        bgr_image = np.asarray(resized, dtype=np.float32)[..., [2, 1, 0]]
        hwc_format = np.ascontiguousarray(np.rollaxis(bgr_image, 2))

        # compute model output
        arguments = {loaded_model.arguments[0]: [hwc_format]}
        output = loaded_model.eval(arguments)

        # return softmax probabilities
        sm = C.softmax(output[0])
        return sm.eval()
    except FileNotFoundError:
        print("Could not open (skipping file): ", image_path)
        return ['None']
        


# Evaluates an image set using the provided model
def eval_test_images(loaded_model, output_file, test_map_file, image_dims, max_images=-1, column_offset=0):
    num_images = sum(1 for line in open(test_map_file))
    if max_images > 0:
        num_images = min(num_images, max_images)
    if isFast:
        num_images = min(num_images, 300) #We will run through fewer images for test run
        
    print("Evaluating model output node '{0}' for {1} images.".format('prediction', num_images))

    pred_count = 0
    correct_count = 0
    np.seterr(over='raise')
    with open(output_file, 'wb') as results_file:
        with open(test_map_file, "r") as input_file:
            for line in input_file:
                tokens = line.rstrip().split('\t')
                img_file = tokens[0 + column_offset]
                probs = eval_single_image(loaded_model, img_file, image_dims)
                
                if probs[0]=='None':
                    print("Eval not possible: ", img_file)
                    continue

                pred_count += 1
                true_label = int(tokens[1 + column_offset])
                predicted_label = np.argmax(probs)
                if predicted_label == true_label:
                    correct_count += 1

                #np.savetxt(results_file, probs[np.newaxis], fmt="%.3f")
                if pred_count % 100 == 0:
                    print("Processed {0} samples ({1:.2%} correct)".format(pred_count, 
                                                                           (float(correct_count) / pred_count)))
                if pred_count >= num_images:
                    break
    print ("{0} of {1} prediction were correct".format(correct_count, pred_count))
    return correct_count, pred_count, (float(correct_count) / pred_count)

# %% [markdown]
# Finally, with all of these helper functions in place we can train the model and evaluate it on our paintings dataset.
#
# You should see the model train and evaluate, with a final accuracy over 90%. At this point you could choose to train longer, or consider taking a look at the confusion matrix to determine if certain flowers are mis-predicted at a greater rate. You could also easily swap out to a different model and see if that performs better, or potentially learn from an earlier point in the model architecture.  The hyper-parameter settings appear at the top of this notebook.

# %% [markdown]
# Azure Blob storage has no real directories:  the container simply stores key-value pairs.  The slash gives an appearance of directories, but these slashes are just part of the key name.  The original tutorial (which this lab is based on) assumes a directory structure and builds a **map.txt** file; however, in this lab, that file was built at the time the image data were uploaded to the container from Azure ML Workbench.
#
# The images are stored with `Train` and `Test` designators with the nested designator giving the class name (i.e. `MonetPaintings` and `VanGoghPaintings` folders). This is quite common, so it is useful to know how to convert that format into one that can be used for constructing the mapping files CNTK expects.

# %%
# Set python version variable 
python_version = sys.version_info.major

# Create map file for CNTK ImageDeserializer
def create_map_file_from_blockblob(azure_file, mapname):
    map_file_name = os.path.abspath(os.path.join(data_root, mapname + ".txt"))
    
    map_file = None

    if python_version == 3: 
        map_file = open(map_file_name , 'w', encoding='utf-8')
    else:
        map_file = open(map_file_name , 'w')

    textLines = spark.sparkContext.textFile(azure_file)
    for row in textLines.collect():
        print(os.path.abspath(os.path.join(data_root, row)))
        try:
            # map_file.write(row)
            print(os.path.abspath(os.path.join(data_root, row)), file=map_file)
        except UnicodeEncodeError:
            print('error ***')
            continue

    map_file.close()  
    print(Path(map_file_name).resolve())
    
    return map_file_name

paintings_data['training_map'] = create_map_file_from_blockblob(paintings_data['azure_training_map'], 'trainmap')
paintings_data['testing_map'] = create_map_file_from_blockblob(paintings_data['azure_testing_map'], 'testmap')
paintings_data
# Out:
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/001c0.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/01110.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/04198.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/061c8.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/061db.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/061dc.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/06c8.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/09100.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/09107.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/09111.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/0918.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/091be.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/0940.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/0978.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/0c110.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/100180.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/100188.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/1001e4.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/1001f9.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/10207.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/10400.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/104110.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/108100.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/10838.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/10a148.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/1101c0.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/1111e7.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/112140.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/11a3f.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/12007.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/1201c7.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/12023.png 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/1203b.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/12107.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/122c0.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/123c3.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/123e8.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/12407.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/124188.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/1241c1.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/1241d3.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/1241d9.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/1241f8.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/1243c.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/1244c.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/1251e4.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/12608.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/1261c0.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/1261c3.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/1261ce.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/12648.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/126ec.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/127af.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/127c0.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/12b103.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/12c181.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/12c1e.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/12f103.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/1321e0.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/13407.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/1341d0.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/13607.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/136107.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/136167.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/1361b.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/1361c4.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/1361e5.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/1361fe.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/13638.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/13647.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/136c4.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/136c6.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/13700.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/13961.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/13c7e.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/13f1e.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/1421e8.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/14801.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/1483f.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/149103.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/156158.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/15a16a.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/15b02.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/1603f.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/1641c0.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/1641f8.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/16602.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/16620.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/1664e.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/168103.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/169120.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/MonetPainting/16b103.jpeg 2
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/PicassoPainting/16c178.jpeg 0
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/16c18.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/16c198.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting/16c1c0.jpeg 1
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/DataSets/Paintings/Train/VanGoghPainting
# DataSets/Paintings/Test/MonetPainting/8329.jpeg 2
# DataSets/Paintings/Test/PicassoPainting/84180.jpeg 0
# DataSets/Paintings/Test/PicassoPainting/8504.jpeg 0
# DataSets/Paintings/Test/PicassoPainting/9370.jpeg 0
# DataSets/Paintings/Test/PicassoPainting/a4f4.jpeg 0
# DataSets/Paintings/Test/MonetPainting/b51e0.jpeg 2
# DataSets/Paintings/Test/MonetPainting/c91f8.jpeg 2
# DataSets/Paintings/Test/VanGoghPainting/c9a4.jpeg 1
# DataSets/Paintings/Test/MonetPainting/d307.jpeg 2
# DataSets/Paintings/Test/MonetPainting/db27.jpeg 2

# %%
# Set python version variable 
python_version = sys.version_info.major

def create_map_file_from_folder(root_folder, class_mapping, include_unknown=False, valid_extensions=['.jpg', '.jpeg', '.png']):
    map_file_name = os.path.join(root_folder, "map.txt")
    
    map_file = None

    if python_version == 3: 
        map_file = open(map_file_name , 'w', encoding='utf-8')
    else:
        map_file = open(map_file_name , 'w')

    print(len(class_mapping))
    for class_id in range(0, len(class_mapping)):
        folder = os.path.abspath(os.path.join(root_folder, class_mapping[class_id]))
        print(folder)
        if os.path.exists(folder):
            print ('path exists')
            for entry in os.listdir(folder):
                filename = os.path.abspath(os.path.join(folder, entry))
                #filename = os.path.join(folder, entry)
                print("Resolved filename: ", Path(filename).resolve())
                if os.path.isfile(filename) and os.path.splitext(filename)[1].lower() in valid_extensions:
                    print('   attempt write')
                    try:
                        map_file.write("{0}\t{1}\n".format(filename, class_id))
                    except UnicodeEncodeError:
                        continue

    if include_unknown:
        for entry in os.listdir(root_folder):
            filename = os.path.abspath(os.path.join(root_folder, entry))
            if os.path.isfile(filename) and os.path.splitext(filename)[1].lower() in valid_extensions:
                try:
                    map_file.write("{0}\t-1\n".format(filename))
                except UnicodeEncodeError:
                    continue
                    
    map_file.close()  
    
    return map_file_name
  

def create_class_mapping_from_folder(root_folder):
    print(root_folder)
    print(Path(root_folder).resolve())
    classes = []
    for _, directories, _ in os.walk(root_folder):
        for directory in directories:
            classes.append(directory)
            print (directory)
    return np.asarray(classes)

#paintings_data['class_mapping'] = create_class_mapping_from_folder(paintings_data['training_folder'])
paintings_data['class_mapping'] = np.array(['MonetPainting','VanGoghPainting','PicassoPainting'])
paintings_data['training_map'] = create_map_file_from_folder(paintings_data['training_folder'], paintings_data['class_mapping'])

# Allows for adding additional images which were never seen
paintings_data['testing_map'] = create_map_file_from_folder(paintings_data['testing_folder'], paintings_data['class_mapping'], 
                                                          include_unknown=True)
paintings_data

# %% [markdown]
# We can now train our model on our small domain and evaluate the results:

# %%
new_file = paintings_data['training_map'] 
print(Path(new_file).resolve())
if not os.path.exists(new_file):
    raise RuntimeError("Map file not found: " + new_file)
    
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image/trainmap.txt
# Out:
# /mnt/resource/hadoop/yarn/local/usercache/livy/appcache/application_1514805782323_0018/Image
# %%
# Trains a transfer learning model
def train_model2(model_details, num_classes, train_map_file,
                learning_params, max_images=-1):
    num_epochs = learning_params['max_epochs']
    epoch_size = sum(1 for line in open(train_map_file))
    print(epoch_size)


paintings_model = {
    'model_file': os.path.join(output_path, 'PaintingsTransferLearning.model'),
    'results_file': os.path.join(output_path, 'PaintingsPredictions.txt'),
    'num_classes': paintings_data['num_classes']
}

if os.path.exists(paintings_model['model_file']) and not force_retraining:
    print("Loading existing model from %s" % paintings_model['model_file'])
    trained_model = C.load_model(paintings_model['model_file'])
else:
    trained_model = train_model2(base_model, 
                                paintings_model['num_classes'],                                
                                paintings_data['training_map'],
                                learning_params)
    #trained_model.save(paintings_model['model_file'])
    #print("Stored paintings trained model at %s" % paintings_model['model_file'])
# Out:
# 322

# %% [markdown]
# Now that the model is trained for animals data. Lets us evaluate the images.

# %%
# evaluate test images
with open(paintings_data['testing_map'], 'r') as input_file:
    for line in input_file:
        tokens = line.rstrip().split('\t')
        img_file = tokens[0]
        true_label = int(tokens[1])
        probs = eval_single_image(trained_model, img_file, base_model['image_dims'])

        if probs[0]=='None':
            continue
        class_probs = np.column_stack((probs, paintings_data['class_mapping'])).tolist()
        class_probs.sort(key=lambda x: float(x[0]), reverse=True)
        predictions = ' '.join(['%s:%.3f' % (class_probs[i][1], float(class_probs[i][0])) \
                                for i in range(0, paintings_model['num_classes'])])
        true_class_name = paintings_data['class_mapping'][true_label] if true_label >= 0 else 'unknown'
        print('Class: %s, predictions: %s, image: %s' % (true_class_name, predictions, img_file))

# %% [markdown]
# ### Evaluate
#
# Evaluate the newly learnt paintings classifier by transfering the learning from a pre-trained ResNet model.

# %%
# Evaluate the test set
predict_correct, predict_total, predict_accuracy = \
   eval_test_images(trained_model, flowers_model['results_file'], flowers_data['testing_map'], base_model['image_dims'])
print("Done. Wrote output to %s" % flowers_model['results_file'])

# %%
# Test: Accuracy on paintings data
print ("Prediction accuracy: {0:.2%}".format(float(predict_correct) / predict_total))

# %% [markdown]
# ### Final Thoughts, and Caveats
#
# Transfer Learning has limitations. If you noticed, we re-trained a model that had been trained on ImageNet images. This meant it already _knew_ what "images" were, and had a good idea on concepts from low-level (stripes, circles) to high-level (dog's noses, cat's ears). Re-training such a model to detect sheep or wolves makes sense, but re-training it to detect vehicles from aerial imagery would be more difficult. You can still use Transfer Learning in these cases, but you might want to just re-use earlier layers of the model (i.e. the early Convolutional layers that have learned more primitive concepts), and you will likely require much more training data.
#
# Adding a catch-all category can be a good idea, but only if the training data for that category contains images that are again sufficiently similar to the images you expect at scoring time. As in the above example, if we train a classifier with images of sheep and wolf and use it to score an image of a bird, the classifier can still only assign a sheep or wolf label, since it does not know any other categories. If we were to add a catch-all category and add training images of birds to it then the classifier might predict the class correctly for the bird image. However, if we present it, e.g., an image of a car, it faces the same problem as before as it knows only sheep, wolf and bird (which we just happened to call called catch-all). Hence, your training data, even for your catch-all, needs to cover sufficiently those concepts and images that you expect later on at scoring time.
